# %%
import pandas as pd

df = pd.read_excel('~/Downloads/cpsaat39.xlsx')
df = df[4:]

# %%
lst = df.loc[4,:].values
lst = lst[~pd.isnull(lst)]
lst = list(lst)
lst
# Out:
# ['Number of workers',
#  'Median weekly earnings',
#  'Number of workers',
#  'Median weekly earnings',
#  'Number of workers',
#  'Median weekly earnings']

# %%
tot_headers = ["Occupation"] + lst
df.columns = tot_headers
df.head(10)
# Out:
#                                            Occupation  Number of workers  \
# 4                                                 NaN  Number of workers
# 5                                                 NaN                NaN
# 6            Total, full-time wage and salary workers             110387
# 7                                                 NaN                NaN
# 8   Management, professional, and related occupations              50023
# 9   Management, business, and financial operations...              20811
# 10                             Management occupations              13517
# 11                                   Chief executives               1157
# 12                    General and operations managers                983
# 13                                        Legislators                 11
#
#     Median weekly earnings  Number of workers  Median weekly earnings  \
# 4   Median weekly earnings  Number of workers  Median weekly earnings
# 5                      NaN                NaN                     NaN
# 6                      984              60911                    1082
# 7                      NaN                NaN                     NaN
# 8                     1356              24090                    1578
# 9                     1461              11082                    1667
# 10                    1541               7770                    1737
# 11                    2402                794                    2712
# 12                    1453                702                    1541
# 13                       –                  9                       –
#
#     Number of workers  Median weekly earnings
# 4   Number of workers  Median weekly earnings
# 5                 NaN                     NaN
# 6               49476                     891
# 7                 NaN                     NaN
# 8               25933                    1164
# 9                9729                    1274
# 10               5747                    1347
# 11                363                    2051
# 12                281                    1241
# 13                  3                       –

# %%
df = df.loc[6:,:]
df.drop([7], inplace = True)
df
# Out:
#                                             Occupation Number of workers  \
# 6             Total, full-time wage and salary workers            110387
# 8    Management, professional, and related occupations             50023
# 9    Management, business, and financial operations...             20811
# 10                              Management occupations             13517
# 11                                    Chief executives              1157
# ..                                                 ...               ...
# 603                          Pumping station operators                17
# 604          Refuse and recyclable material collectors                70
# 605                      Other material moving workers                46
# 606                                                NaN               NaN
# 607  NOTE: Updated population controls are introduc...               NaN
#
#     Median weekly earnings Number of workers Median weekly earnings  \
# 6                      984             60911                   1082
# 8                     1356             24090                   1578
# 9                     1461             11082                   1667
# 10                    1541              7770                   1737
# 11                    2402               794                   2712
# ..                     ...               ...                    ...
# 603                      –                17                      –
# 604                    680                64                    698
# 605                      –                41                      –
# 606                    NaN               NaN                    NaN
# 607                    NaN               NaN                    NaN
#
#     Number of workers Median weekly earnings
# 6               49476                    891
# 8               25933                   1164
# 9                9729                   1274
# 10               5747                   1347
# 11                363                   2051
# ..                ...                    ...
# 603                 0                      –
# 604                 6                      –
# 605                 5                      –
# 606               NaN                    NaN
# 607               NaN                    NaN
#
# [601 rows x 7 columns]

# %%
df.dropna(subset = ["Occupation"], inplace = True)
df.set_index('Occupation', inplace = True)
df.head()
# Out:
#                                                    Number of workers  \
# Occupation
# Total, full-time wage and salary workers                      110387
# Management, professional, and related occupations              50023
# Management, business, and financial operations ...             20811
# Management occupations                                         13517
# Chief executives                                                1157
#
#                                                    Median weekly earnings  \
# Occupation
# Total, full-time wage and salary workers                              984
# Management, professional, and related occupations                    1356
# Management, business, and financial operations ...                   1461
# Management occupations                                               1541
# Chief executives                                                     2402
#
#                                                    Number of workers  \
# Occupation
# Total, full-time wage and salary workers                       60911
# Management, professional, and related occupations              24090
# Management, business, and financial operations ...             11082
# Management occupations                                          7770
# Chief executives                                                 794
#
#                                                    Median weekly earnings  \
# Occupation
# Total, full-time wage and salary workers                             1082
# Management, professional, and related occupations                    1578
# Management, business, and financial operations ...                   1667
# Management occupations                                               1737
# Chief executives                                                     2712
#
#                                                    Number of workers  \
# Occupation
# Total, full-time wage and salary workers                       49476
# Management, professional, and related occupations              25933
# Management, business, and financial operations ...              9729
# Management occupations                                          5747
# Chief executives                                                 363
#
#                                                    Median weekly earnings
# Occupation
# Total, full-time wage and salary workers                              891
# Management, professional, and related occupations                    1164
# Management, business, and financial operations ...                   1274
# Management occupations                                               1347
# Chief executives                                                     2051

# %%
cols = df.columns
new_col_list = list()
i = 0
for col in cols:
    if i in (0,1):
        new_col_list.append(col+" (Total)")
    elif i in (2,3):
        new_col_list.append(col+" (Male)")
    else:
        new_col_list.append(col+" (Female)")
    i = i+1
df.columns = new_col_list
df.head()
# Out:
#                                                    Number of workers (Total)  \
# Occupation
# Total, full-time wage and salary workers                              110387
# Management, professional, and related occupations                      50023
# Management, business, and financial operations ...                     20811
# Management occupations                                                 13517
# Chief executives                                                        1157
#
#                                                    Median weekly earnings (Total)  \
# Occupation
# Total, full-time wage and salary workers                                      984
# Management, professional, and related occupations                            1356
# Management, business, and financial operations ...                           1461
# Management occupations                                                       1541
# Chief executives                                                             2402
#
#                                                    Number of workers (Male)  \
# Occupation
# Total, full-time wage and salary workers                              60911
# Management, professional, and related occupations                     24090
# Management, business, and financial operations ...                    11082
# Management occupations                                                 7770
# Chief executives                                                        794
#
#                                                    Median weekly earnings (Male)  \
# Occupation
# Total, full-time wage and salary workers                                    1082
# Management, professional, and related occupations                           1578
# Management, business, and financial operations ...                          1667
# Management occupations                                                      1737
# Chief executives                                                            2712
#
#                                                    Number of workers (Female)  \
# Occupation
# Total, full-time wage and salary workers                                49476
# Management, professional, and related occupations                       25933
# Management, business, and financial operations ...                       9729
# Management occupations                                                   5747
# Chief executives                                                          363
#
#                                                    Median weekly earnings (Female)
# Occupation
# Total, full-time wage and salary workers                                       891
# Management, professional, and related occupations                             1164
# Management, business, and financial operations ...                            1274
# Management occupations                                                        1347
# Chief executives                                                              2051

# %%
df['Number of Worker Discrepancy'] = df['Number of workers (Male)'] - df['Number of workers (Female)']
df.head()
df2 = df.sort_values(by = "Number of Worker Discrepancy", ascending = False)
df2.dropna(inplace = True)
df2
# Out:
#                                                     Number of workers (Total)  \
# Occupation
# Total, full-time wage and salary workers                               110387
# Natural resources, construction, and maintenanc...                      10690
# Production, transportation, and material moving...                      14738
# Construction and extraction occupations                                  5826
# Transportation and material moving occupations                           7917
# ...                                                                       ...
# Professional and related occupations                                    29213
# Education, training, and library occupations                             7012
# Healthcare practitioners and technical occupations                       7504
# Sales and office occupations                                            21165
# Office and administrative support occupations                           12207
#
#                                                     Median weekly earnings (Total)  \
# Occupation
# Total, full-time wage and salary workers                                       984
# Natural resources, construction, and maintenanc...                             905
# Production, transportation, and material moving...                             746
# Construction and extraction occupations                                        906
# Transportation and material moving occupations                                 719
# ...                                                                            ...
# Professional and related occupations                                          1270
# Education, training, and library occupations                                  1096
# Healthcare practitioners and technical occupations                            1227
# Sales and office occupations                                                   809
# Office and administrative support occupations                                  781
#
#                                                     Number of workers (Male)  \
# Occupation
# Total, full-time wage and salary workers                               60911
# Natural resources, construction, and maintenanc...                     10152
# Production, transportation, and material moving...                     11494
# Construction and extraction occupations                                 5635
# Transportation and material moving occupations                          6439
# ...                                                                      ...
# Professional and related occupations                                   13008
# Education, training, and library occupations                            1870
# Healthcare practitioners and technical occupations                      1921
# Sales and office occupations                                            8435
# Office and administrative support occupations                           3445
#
#                                                     Median weekly earnings (Male)  \
# Occupation
# Total, full-time wage and salary workers                                     1082
# Natural resources, construction, and maintenanc...                            917
# Production, transportation, and material moving...                            796
# Construction and extraction occupations                                       910
# Transportation and material moving occupations                                759
# ...                                                                           ...
# Professional and related occupations                                         1532
# Education, training, and library occupations                                 1327
# Healthcare practitioners and technical occupations                           1506
# Sales and office occupations                                                  956
# Office and administrative support occupations                                 868
#
#                                                     Number of workers (Female)  \
# Occupation
# Total, full-time wage and salary workers                                 49476
# Natural resources, construction, and maintenanc...                         538
# Production, transportation, and material moving...                        3243
# Construction and extraction occupations                                    191
# Transportation and material moving occupations                            1478
# ...                                                                        ...
# Professional and related occupations                                     16204
# Education, training, and library occupations                              5142
# Healthcare practitioners and technical occupations                        5584
# Sales and office occupations                                             12729
# Office and administrative support occupations                             8762
#
#                                                     Median weekly earnings (Female)  \
# Occupation
# Total, full-time wage and salary workers                                        891
# Natural resources, construction, and maintenanc...                              682
# Production, transportation, and material moving...                              614
# Construction and extraction occupations                                         796
# Transportation and material moving occupations                                  600
# ...                                                                             ...
# Professional and related occupations                                           1121
# Education, training, and library occupations                                   1026
# Healthcare practitioners and technical occupations                             1153
# Sales and office occupations                                                    746
# Office and administrative support occupations                                   756
#
#                                                     Number of Worker Discrepancy  \
# Occupation
# Total, full-time wage and salary workers                                   11435
# Natural resources, construction, and maintenanc...                          9614
# Production, transportation, and material moving...                          8251
# Construction and extraction occupations                                     5444
# Transportation and material moving occupations                              4961
# ...                                                                          ...
# Professional and related occupations                                       -3196
# Education, training, and library occupations                               -3272
# Healthcare practitioners and technical occupations                         -3663
# Sales and office occupations                                               -4294
# Office and administrative support occupations                              -5317
#
#                                                     Avg. Difference in Male & Female Salaries
# Occupation
# Total, full-time wage and salary workers                                                 9932
# Natural resources, construction, and maintenanc...                                      12220
# Production, transportation, and material moving...                                       9464
# Construction and extraction occupations                                                  5928
# Transportation and material moving occupations                                           8268
# ...                                                                                       ...
# Professional and related occupations                                                    21372
# Education, training, and library occupations                                            15652
# Healthcare practitioners and technical occupations                                      18356
# Sales and office occupations                                                            10920
# Office and administrative support occupations                                            5824
#
# [150 rows x 8 columns]

# %%
df3
# Out:
#                                                     Number of workers (Total)  \
# Occupation
# Management, professional, and related occupations                       50023
# Management, business, and financial operations ...                      20811
# Management occupations                                                  13517
# Chief executives                                                         1157
# General and operations managers                                           983
#
#                                                     Median weekly earnings (Total)  \
# Occupation
# Management, professional, and related occupations                             1356
# Management, business, and financial operations ...                            1461
# Management occupations                                                        1541
# Chief executives                                                              2402
# General and operations managers                                               1453
#
#                                                     Number of workers (Male)  \
# Occupation
# Management, professional, and related occupations                      24090
# Management, business, and financial operations ...                     11082
# Management occupations                                                  7770
# Chief executives                                                         794
# General and operations managers                                          702
#
#                                                     Median weekly earnings (Male)  \
# Occupation
# Management, professional, and related occupations                            1578
# Management, business, and financial operations ...                           1667
# Management occupations                                                       1737
# Chief executives                                                             2712
# General and operations managers                                              1541
#
#                                                     Number of workers (Female)  \
# Occupation
# Management, professional, and related occupations                        25933
# Management, business, and financial operations ...                        9729
# Management occupations                                                    5747
# Chief executives                                                           363
# General and operations managers                                            281
#
#                                                     Median weekly earnings (Female)  \
# Occupation
# Management, professional, and related occupations                              1164
# Management, business, and financial operations ...                             1274
# Management occupations                                                         1347
# Chief executives                                                               2051
# General and operations managers                                                1241
#
#                                                     Number of Worker Discrepancy  \
# Occupation
# Management, professional, and related occupations                          -1843
# Management, business, and financial operations ...                          1353
# Management occupations                                                      2023
# Chief executives                                                             431
# General and operations managers                                              421
#
#                                                     Avg. Difference in Male & Female Salaries
# Occupation
# Management, professional, and related occupations                                       21528
# Management, business, and financial operations ...                                      20436
# Management occupations                                                                  20280
# Chief executives                                                                        34372
# General and operations managers                                                         15600

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df3 = df2.iloc[0:5,:]


plt.style.use('seaborn-dark-palette')
plt.figure(figsize = (12,10))
plt.style.use('ggplot')
sns.barplot(x = df3.index, y = 'Number of Worker Discrepancy', data = df3)
ax = sns.countplot(x=df3.index, data=df3)
plt.ylabel("Number of Worker Difference Between Male & Female", fontweight = "bold")
plt.setp(ax.get_xticklabels(), fontweight="bold")
plt.title('Jobs where the Difference between Male & Female Workers are Highest')
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")

plt.tight_layout()
plt.savefig('Number of Worker Diff.jpeg')
plt.show()

# %%
import numpy as np
df.replace('–', np.nan, inplace = True)
df.dropna(inplace = True)
df = df.astype('int')
df['Avg. Difference in Male & Female Salaries'] = (df['Median weekly earnings (Male)'] - df['Median weekly earnings (Female)'])*52
df.head()
# Out:
#                                                     Number of workers (Total)  \
# Occupation
# Total, full-time wage and salary workers                               110387
# Management, professional, and related occupations                       50023
# Management, business, and financial operations ...                      20811
# Management occupations                                                  13517
# Chief executives                                                         1157
#
#                                                     Median weekly earnings (Total)  \
# Occupation
# Total, full-time wage and salary workers                                       984
# Management, professional, and related occupations                             1356
# Management, business, and financial operations ...                            1461
# Management occupations                                                        1541
# Chief executives                                                              2402
#
#                                                     Number of workers (Male)  \
# Occupation
# Total, full-time wage and salary workers                               60911
# Management, professional, and related occupations                      24090
# Management, business, and financial operations ...                     11082
# Management occupations                                                  7770
# Chief executives                                                         794
#
#                                                     Median weekly earnings (Male)  \
# Occupation
# Total, full-time wage and salary workers                                     1082
# Management, professional, and related occupations                            1578
# Management, business, and financial operations ...                           1667
# Management occupations                                                       1737
# Chief executives                                                             2712
#
#                                                     Number of workers (Female)  \
# Occupation
# Total, full-time wage and salary workers                                 49476
# Management, professional, and related occupations                        25933
# Management, business, and financial operations ...                        9729
# Management occupations                                                    5747
# Chief executives                                                           363
#
#                                                     Median weekly earnings (Female)  \
# Occupation
# Total, full-time wage and salary workers                                        891
# Management, professional, and related occupations                              1164
# Management, business, and financial operations ...                             1274
# Management occupations                                                         1347
# Chief executives                                                               2051
#
#                                                     Number of Worker Discrepancy  \
# Occupation
# Total, full-time wage and salary workers                                   11435
# Management, professional, and related occupations                          -1843
# Management, business, and financial operations ...                          1353
# Management occupations                                                      2023
# Chief executives                                                             431
#
#                                                     Avg. Difference in Male & Female Salaries
# Occupation
# Total, full-time wage and salary workers                                                 9932
# Management, professional, and related occupations                                       21528
# Management, business, and financial operations ...                                      20436
# Management occupations                                                                  20280
# Chief executives                                                                        34372

# %%
df2 = df[df['Median weekly earnings (Male)'] > 1000]
df2 = df2[df2['Median weekly earnings (Female)'] > 1000]
df2.sort_values(by = "Avg. Difference in Male & Female Salaries", ascending = False)
# Out:
#                                                    Number of workers (Total)  \
# Occupation
# Legal occupations                                                       1410
# Medical scientists                                                       114
# Chief executives                                                        1157
# Lawyers                                                                  821
# Financial managers                                                      1228
# ...                                                                      ...
# Special education teachers                                               301
# Civil engineers                                                          370
# Compliance officers                                                      286
# Wholesale and retail buyers, except farm products                        130
# Producers and directors                                                  123
#
#                                                    Median weekly earnings (Total)  \
# Occupation
# Legal occupations                                                            1540
# Medical scientists                                                           1612
# Chief executives                                                             2402
# Lawyers                                                                      2097
# Financial managers                                                           1492
# ...                                                                           ...
# Special education teachers                                                   1044
# Civil engineers                                                              1611
# Compliance officers                                                          1372
# Wholesale and retail buyers, except farm products                            1053
# Producers and directors                                                      1499
#
#                                                    Number of workers (Male)  \
# Occupation
# Legal occupations                                                       599
# Medical scientists                                                       53
# Chief executives                                                        794
# Lawyers                                                                 470
# Financial managers                                                      603
# ...                                                                     ...
# Special education teachers                                               58
# Civil engineers                                                         317
# Compliance officers                                                     119
# Wholesale and retail buyers, except farm products                        64
# Producers and directors                                                  63
#
#                                                    Median weekly earnings (Male)  \
# Occupation
# Legal occupations                                                           2275
# Medical scientists                                                          2103
# Chief executives                                                            2712
# Lawyers                                                                     2324
# Financial managers                                                          1880
# ...                                                                          ...
# Special education teachers                                                  1102
# Civil engineers                                                             1629
# Compliance officers                                                         1373
# Wholesale and retail buyers, except farm products                           1047
# Producers and directors                                                     1458
#
#                                                    Number of workers (Female)  \
# Occupation
# Legal occupations                                                         812
# Medical scientists                                                         60
# Chief executives                                                          363
# Lawyers                                                                   351
# Financial managers                                                        624
# ...                                                                       ...
# Special education teachers                                                244
# Civil engineers                                                            54
# Compliance officers                                                       167
# Wholesale and retail buyers, except farm products                          66
# Producers and directors                                                    60
#
#                                                    Median weekly earnings (Female)  \
# Occupation
# Legal occupations                                                             1252
# Medical scientists                                                            1372
# Chief executives                                                              2051
# Lawyers                                                                       1665
# Financial managers                                                            1242
# ...                                                                            ...
# Special education teachers                                                    1036
# Civil engineers                                                               1588
# Compliance officers                                                           1371
# Wholesale and retail buyers, except farm products                             1066
# Producers and directors                                                       1548
#
#                                                    Number of Worker Discrepancy  \
# Occupation
# Legal occupations                                                          -213
# Medical scientists                                                           -7
# Chief executives                                                            431
# Lawyers                                                                     119
# Financial managers                                                          -21
# ...                                                                         ...
# Special education teachers                                                 -186
# Civil engineers                                                             263
# Compliance officers                                                         -48
# Wholesale and retail buyers, except farm products                            -2
# Producers and directors                                                       3
#
#                                                    Avg. Difference in Male & Female Salaries
# Occupation
# Legal occupations                                                                      53196
# Medical scientists                                                                     38012
# Chief executives                                                                       34372
# Lawyers                                                                                34268
# Financial managers                                                                     33176
# ...                                                                                      ...
# Special education teachers                                                              3432
# Civil engineers                                                                         2132
# Compliance officers                                                                      104
# Wholesale and retail buyers, except farm products                                       -988
# Producers and directors                                                                -4680
#
# [70 rows x 8 columns]

# %%
df2.sort_values(by = "Avg. Difference in Male & Female Salaries", inplace = True, ascending = False)

# %%
df3 = df2.iloc[0:5,:]

plt.figure(figsize = (12,10))
sns.barplot(x = df3.index, y = "Avg. Difference in Male & Female Salaries", data = df3)
# ax = sns.countplot(x=df3.index, data=df3)
plt.ylabel("Avg. Difference in Male & Female Salaries")
plt.title('Jobs where the Salary Difference between Male & Female are the Highest')
plt.savefig('Salary Diff. M&F.jpeg')
# ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
# plt.tight_layout()
# plt.show()

# %%
df_pov = pd.read_excel("~/Downloads/working-poor-tables-2019.xlsx")
df_pov = df_pov.iloc[2:11,:13]
df_pov.columns = ['Characteristic'] + list(range(2008,2020))
df_pov
# Out:
#                                Characteristic      2008      2009      2010  \
# 2                   Total in the labor force¹  147838.0  147902.0  146859.0
# 3             In poverty                         8883.0   10391.0   10512.0
# 4      Working poor rate                            6.0       7.0       7.2
# 5            Unrelated individuals              32785.0   33798.0   34099.0
# 6             In poverty                         3275.0    3947.0    3947.0
# 7      Working poor rate                           10.0      11.7      11.6
# 8                           Primary families²   65907.0   65467.0   64931.0
# 9              In poverty                        4538.0    5193.0    5269.0
# 10     Working poor rate                            6.9       7.9       8.1
#
#         2011      2012      2013      2014      2015      2016      2017  \
# 2   147475.0  148735.0  149483.0  150319.0  152230.0  153364.0  154762.0
# 3    10382.0   10612.0   10450.0    9487.0    8560.0    7572.0    6946.0
# 4        7.0       7.1       7.0       6.3       5.6       4.9       4.5
# 5    33731.0   34810.0   35061.0   35018.0   35953.0   35789.0   36959.0
# 6     3621.0    3851.0    4141.0    3395.0    3137.0    2792.0    2524.0
# 7       10.7      11.1      11.8       9.7       8.7       7.8       6.8
# 8    66225.0   66541.0   66462.0   66732.0   67193.0   67628.0   67588.0
# 9     5469.0    5478.0    5137.0    5108.0    4607.0    4082.0    3854.0
# 10       8.3       8.2       7.7       7.7       6.9       6.0       5.7
#
#         2018      2019
# 2   156454.0  157769.0
# 3     6964.0    6318.0
# 4        4.5       4.0
# 5    37082.0   36805.0
# 6     2684.0    2445.0
# 7        7.2       6.6
# 8    68099.0   68318.0
# 9     3628.0    3232.0
# 10       5.3       4.7

# %%
df_povT = df_pov.T
df_povT.columns = df_povT.iloc[0,:]
df_povT = df_povT.iloc[1:,:]
df_povT
# Out:
# Characteristic Total in the labor force¹    In poverty                       \
# 2008                            147838.0                             8883.0
# 2009                            147902.0                            10391.0
# 2010                            146859.0                            10512.0
# 2011                            147475.0                            10382.0
# 2012                            148735.0                            10612.0
# 2013                            149483.0                            10450.0
# 2014                            150319.0                             9487.0
# 2015                            152230.0                             8560.0
# 2016                            153364.0                             7572.0
# 2017                            154762.0                             6946.0
# 2018                            156454.0                             6964.0
# 2019                            157769.0                             6318.0
#
# Characteristic    Working poor rate                       \
# 2008                                                 6.0
# 2009                                                 7.0
# 2010                                                 7.2
# 2011                                                 7.0
# 2012                                                 7.1
# 2013                                                 7.0
# 2014                                                 6.3
# 2015                                                 5.6
# 2016                                                 4.9
# 2017                                                 4.5
# 2018                                                 4.5
# 2019                                                 4.0
#
# Characteristic Unrelated individuals             \
# 2008                                    32785.0
# 2009                                    33798.0
# 2010                                    34099.0
# 2011                                    33731.0
# 2012                                    34810.0
# 2013                                    35061.0
# 2014                                    35018.0
# 2015                                    35953.0
# 2016                                    35789.0
# 2017                                    36959.0
# 2018                                    37082.0
# 2019                                    36805.0
#
# Characteristic    In poverty                       \
# 2008                                       3275.0
# 2009                                       3947.0
# 2010                                       3947.0
# 2011                                       3621.0
# 2012                                       3851.0
# 2013                                       4141.0
# 2014                                       3395.0
# 2015                                       3137.0
# 2016                                       2792.0
# 2017                                       2524.0
# 2018                                       2684.0
# 2019                                       2445.0
#
# Characteristic    Working poor rate                      Primary families²  \
# 2008                                                10.0           65907.0
# 2009                                                11.7           65467.0
# 2010                                                11.6           64931.0
# 2011                                                10.7           66225.0
# 2012                                                11.1           66541.0
# 2013                                                11.8           66462.0
# 2014                                                 9.7           66732.0
# 2015                                                 8.7           67193.0
# 2016                                                 7.8           67628.0
# 2017                                                 6.8           67588.0
# 2018                                                 7.2           68099.0
# 2019                                                 6.6           68318.0
#
# Characteristic    In poverty                      \
# 2008                                      4538.0
# 2009                                      5193.0
# 2010                                      5269.0
# 2011                                      5469.0
# 2012                                      5478.0
# 2013                                      5137.0
# 2014                                      5108.0
# 2015                                      4607.0
# 2016                                      4082.0
# 2017                                      3854.0
# 2018                                      3628.0
# 2019                                      3232.0
#
# Characteristic    Working poor rate
# 2008                                                 6.9
# 2009                                                 7.9
# 2010                                                 8.1
# 2011                                                 8.3
# 2012                                                 8.2
# 2013                                                 7.7
# 2014                                                 7.7
# 2015                                                 6.9
# 2016                                                 6.0
# 2017                                                 5.7
# 2018                                                 5.3
# 2019                                                 4.7

# %%
df_povT.rename(index = {"Characteristic":"Year"}, inplace = True)
df_povT.columns = ['Total in the labor force','In poverty','Working poor rate for labor force',"Unrelated Individuals",'In poverty',"Working poor rate for Unrelated Families","Primary Families",'In poverty',"Working poor rate for primary families"]
df_povT
# Out:
#      Total in the labor force In poverty Working poor rate for labor force  \
# 2008                 147838.0     8883.0                               6.0
# 2009                 147902.0    10391.0                               7.0
# 2010                 146859.0    10512.0                               7.2
# 2011                 147475.0    10382.0                               7.0
# 2012                 148735.0    10612.0                               7.1
# 2013                 149483.0    10450.0                               7.0
# 2014                 150319.0     9487.0                               6.3
# 2015                 152230.0     8560.0                               5.6
# 2016                 153364.0     7572.0                               4.9
# 2017                 154762.0     6946.0                               4.5
# 2018                 156454.0     6964.0                               4.5
# 2019                 157769.0     6318.0                               4.0
#
#      Unrelated Individuals In poverty  \
# 2008               32785.0     3275.0
# 2009               33798.0     3947.0
# 2010               34099.0     3947.0
# 2011               33731.0     3621.0
# 2012               34810.0     3851.0
# 2013               35061.0     4141.0
# 2014               35018.0     3395.0
# 2015               35953.0     3137.0
# 2016               35789.0     2792.0
# 2017               36959.0     2524.0
# 2018               37082.0     2684.0
# 2019               36805.0     2445.0
#
#      Working poor rate for Unrelated Families Primary Families In poverty  \
# 2008                                     10.0          65907.0     4538.0
# 2009                                     11.7          65467.0     5193.0
# 2010                                     11.6          64931.0     5269.0
# 2011                                     10.7          66225.0     5469.0
# 2012                                     11.1          66541.0     5478.0
# 2013                                     11.8          66462.0     5137.0
# 2014                                      9.7          66732.0     5108.0
# 2015                                      8.7          67193.0     4607.0
# 2016                                      7.8          67628.0     4082.0
# 2017                                      6.8          67588.0     3854.0
# 2018                                      7.2          68099.0     3628.0
# 2019                                      6.6          68318.0     3232.0
#
#      Working poor rate for primary families
# 2008                                    6.9
# 2009                                    7.9
# 2010                                    8.1
# 2011                                    8.3
# 2012                                    8.2
# 2013                                    7.7
# 2014                                    7.7
# 2015                                    6.9
# 2016                                    6.0
# 2017                                    5.7
# 2018                                    5.3
# 2019                                    4.7

# %%
plt.figure(figsize = (10,8))
df_povT = df_povT.astype('int')
sns.regplot(data = df_povT, x = df_povT.index, y = "Working poor rate for labor force")
plt.title('Year vs. Working Poor Rate for Labor Force')
# Out:
# Text(0.5, 1.0, 'Year vs. Working Poor Rate for Labor Force')

# %%
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(df_povT.index,df_povT["Working poor rate for labor force"])

# %%
print('The formula of the graph follows this formula')
print(slope,"(year)","+",intercept)
print("-------------------------------------------------------------------")
print("This formula takes an r2 - value of approximately",r_value**2)
print("-------------------------------------------------------------------")
print("With this model, we can predict a ",round(slope*2024 + intercept,2),"% poverty rate among working class citizens in 2024 barring any strong changes")
# Out:
# The formula of the graph follows this formula
# -0.32167832167832167 (year) + 653.3659673659673
# -------------------------------------------------------------------
# This formula takes an r2 - value of approximately 0.7159936837356192
# -------------------------------------------------------------------
# With this model, we can predict a  2.29 % poverty rate among working class citizens in 2024 barring any strong changes

# %%
import os

directory = "/Users/rishabhagarwal/Downloads/Industry over Last 10 Years"
pathList = list()
for path in os.listdir(directory):
    filePath = os.path.join(directory, path)
    pathList.append(filePath)
    
pathList
# Out:
# ['/Users/rishabhagarwal/Downloads/Industry over Last 10 Years/SeriesReport-20210809201250_081c32.xlsx',
#  '/Users/rishabhagarwal/Downloads/Industry over Last 10 Years/SeriesReport-20210809201252_a7d366.xlsx',
#  '/Users/rishabhagarwal/Downloads/Industry over Last 10 Years/SeriesReport-20210809201333_6b3c03.xlsx',
#  '/Users/rishabhagarwal/Downloads/Industry over Last 10 Years/SeriesReport-20210809201319_f451a3.xlsx',
#  '/Users/rishabhagarwal/Downloads/Industry over Last 10 Years/SeriesReport-20210809201258_a465d6.xlsx',
#  '/Users/rishabhagarwal/Downloads/Industry over Last 10 Years/SeriesReport-20210809201310_e8a283.xlsx',
#  '/Users/rishabhagarwal/Downloads/Industry over Last 10 Years/SeriesReport-20210809201256_eac72b.xlsx',
#  '/Users/rishabhagarwal/Downloads/Industry over Last 10 Years/SeriesReport-20210809201316_c691e3.xlsx',
#  '/Users/rishabhagarwal/Downloads/Industry over Last 10 Years/SeriesReport-20210809201243_1e667e.xlsx',
#  '/Users/rishabhagarwal/Downloads/Industry over Last 10 Years/SeriesReport-20210809201226_a8d181.xlsx',
#  '/Users/rishabhagarwal/Downloads/Industry over Last 10 Years/SeriesReport-20210809201322_a36a79.xlsx',
#  '/Users/rishabhagarwal/Downloads/Industry over Last 10 Years/SeriesReport-20210809201312_6abf07.xlsx',
#  '/Users/rishabhagarwal/Downloads/Industry over Last 10 Years/SeriesReport-20210809201254_9ebb5a.xlsx']

# %%
import pandas as pd

i = 0
for path in pathList:
    i = i + 1
    df = pd.read_excel(path)
    name = df.iloc[8,1]
    df = df.iloc[18:,:]
    strng = "Avg. # of Workers for "+name
    df.columns = ['Year',"Qtr1","Qtr2","Qtr3","Qtr4"]
    df = df.iloc[1:,:]
    df[strng] = (df['Qtr1'] + df["Qtr2"] + df['Qtr3'] + df["Qtr4"])/4
    df.dropna(inplace = True)
    df.set_index("Year", inplace = True)
    df = pd.DataFrame(df.iloc[:,4])
    if i == 1:
        tot_df = df
    else:
        tot_df = pd.concat([tot_df,df],axis = 1)
        
tot_df
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:221: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#      Avg. # of Workers for Construction and extraction occupations  \
# Year
# 2011                                             5031.5
# 2012                                             5102.5
# 2013                                            5353.25
# 2014                                             5755.5
# 2015                                            5722.25
# 2016                                             5978.5
# 2017                                            6146.75
# 2018                                            6413.75
# 2019                                             6467.0
# 2020                                             5826.0
#
#      Avg. # of Workers for Installation, maintenance, and repair occupations  \
# Year
# 2011                                            4158.75
# 2012                                            4088.25
# 2013                                            4267.75
# 2014                                            4231.25
# 2015                                            4301.25
# 2016                                            4201.75
# 2017                                            4400.25
# 2018                                             4282.0
# 2019                                            4304.25
# 2020                                            4077.25
#
#      Avg. # of Workers for Office and administrative support occupations  \
# Year
# 2011                                            13694.5
# 2012                                            13682.5
# 2013                                            13744.0
# 2014                                           13775.75
# 2015                                            13894.0
# 2016                                           13865.75
# 2017                                           13733.25
# 2018                                            13637.5
# 2019                                            13953.5
# 2020                                            12206.5
#
#      Avg. # of Workers for Service occupations  \
# Year
# 2011                                   14378.5
# 2012                                   14839.5
# 2013                                  15052.25
# 2014                                  15019.25
# 2015                                  15278.75
# 2016                                  15908.25
# 2017                                  16044.25
# 2018                                  16288.25
# 2019                                   16558.0
# 2020                                  13771.25
#
#      Avg. # of Workers for Transportation and material moving occupations  \
# Year
# 2011                                            6275.25
# 2012                                             6415.0
# 2013                                             6623.0
# 2014                                            6844.75
# 2015                                             6953.0
# 2016                                            7093.25
# 2017                                             7235.5
# 2018                                             7542.5
# 2019                                            7612.25
# 2020                                            7917.25
#
#      Avg. # of Workers for Management, professional and related occupations  \
# Year
# 2011                                           39791.75
# 2012                                            40984.0
# 2013                                            41820.0
# 2014                                            43016.0
# 2015                                           44844.25
# 2016                                            45929.5
# 2017                                            47207.5
# 2018                                            48808.0
# 2019                                           50118.75
# 2020                                           50023.25
#
#      Avg. # of Workers for Production occupations  \
# Year
# 2011                                      7057.75
# 2012                                       7427.0
# 2013                                       7307.0
# 2014                                       7481.0
# 2015                                       7550.5
# 2016                                      7512.75
# 2017                                       7589.0
# 2018                                       7668.0
# 2019                                       7741.0
# 2020                                      6820.25
#
#      Avg. # of Workers for Professional and related occupations  \
# Year
# 2011                                            23730.0
# 2012                                           23993.25
# 2013                                            24683.0
# 2014                                           25454.75
# 2015                                            26423.0
# 2016                                            26906.5
# 2017                                            27793.5
# 2018                                           28945.25
# 2019                                           29422.75
# 2020                                           29212.75
#
#      Avg. # of Workers for Farming, fishing, and forestry occupations  \
# Year
# 2011                                              775.0
# 2012                                             776.75
# 2013                                             719.75
# 2014                                             775.75
# 2015                                              810.0
# 2016                                              842.5
# 2017                                              962.0
# 2018                                              850.0
# 2019                                             899.75
# 2020                                              787.0
#
#      Avg. # of Workers for Natural resources, construction, and maintenance occupations  \
# Year
# 2011                                             9965.0
# 2012                                             9967.5
# 2013                                           10340.25
# 2014                                            10763.5
# 2015                                           10833.75
# 2016                                            11022.5
# 2017                                           11509.25
# 2018                                            11546.0
# 2019                                            11671.0
# 2020                                           10690.25
#
#      Avg. # of Workers for Sales and office occupations  \
# Year
# 2011                                            22989.0
# 2012                                            23115.5
# 2013                                           23119.75
# 2014                                           23402.25
# 2015                                            23620.0
# 2016                                           23624.75
# 2017                                           23686.25
# 2018                                           23714.25
# 2019                                            23883.0
# 2020                                            21165.0
#
#      Avg. # of Workers for Management, business, and financial operations occupations  \
# Year
# 2011                                           16061.25
# 2012                                           16990.75
# 2013                                           17136.75
# 2014                                           17561.25
# 2015                                            18421.5
# 2016                                            19023.0
# 2017                                           19413.75
# 2018                                            19862.5
# 2019                                           20695.75
# 2020                                            20810.5
#
#      Avg. # of Workers for Production, transportation, and material moving occupations
# Year
# 2011                                            13333.0
# 2012                                           13842.25
# 2013                                            13930.0
# 2014                                            14326.0
# 2015                                           14503.75
# 2016                                           14606.25
# 2017                                            14824.5
# 2018                                           15210.25
# 2019                                           15353.25
# 2020                                            14737.5

# %%
import matplotlib.pyplot as plt

colList = tot_df.columns
df = df.astype('float')
i = 0
fig, ax = plt.subplots(4,4, figsize = (15,15))

i = 0
j = 0

names = ['Growth of Construction Roles','Growth of Maintenance Roles',"Growth of Admin Support Roles","Growth of Service Roles",'Growth of Transportation Roles',"Growth of Management Roles","Growth of Production Roles","Growth of Professionals Roles",'Growth of Farming Roles',"Natural Resource Roles","Growth of Sales Roles","Growth of Finance Roles","Growth of Production Roles"]

q = 0
for col in colList:
    print(col)
    print(names[q])
    ax[i][j].plot(tot_df.index,tot_df[col])
    print(q)
    ax[i][j].set_title(names[q])
    i = i + 1
    q = q + 1
    if i == 4:
        i = 0
        j = j + 1
plt.savefig('Worker Role Growth.jpeg')
# Out:
# Avg. # of Workers for Construction and extraction occupations
# Growth of Construction Roles
# 0
# Avg. # of Workers for Installation, maintenance, and repair occupations
# Growth of Maintenance Roles
# 1
# Avg. # of Workers for Office and administrative support occupations
# Growth of Admin Support Roles
# 2
# Avg. # of Workers for Service occupations
# Growth of Service Roles
# 3
# Avg. # of Workers for Transportation and material moving occupations
# Growth of Transportation Roles
# 4
# Avg. # of Workers for Management, professional and related occupations
# Growth of Management Roles
# 5
# Avg. # of Workers for Production occupations
# Growth of Production Roles
# 6
# Avg. # of Workers for Professional and related occupations
# Growth of Professionals Roles
# 7
# Avg. # of Workers for Farming, fishing, and forestry occupations
# Growth of Farming Roles
# 8
# Avg. # of Workers for Natural resources, construction, and maintenance occupations
# Natural Resource Roles
# 9
# Avg. # of Workers for Sales and office occupations
# Growth of Sales Roles
# 10
# Avg. # of Workers for Management, business, and financial operations occupations
# Growth of Finance Roles
# 11
# Avg. # of Workers for Production, transportation, and material moving occupations
# Growth of Production Roles
# 12
